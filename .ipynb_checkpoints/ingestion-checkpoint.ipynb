# %%
# Install dependencies if needed
# !pip install langchain langchain-experimental langchain-chroma pillow open_clip_torch torch matplotlib unstructured pydantic
import os
from textbook_loading import (
    load_book,
    clean_and_categorize_elements,
    summarize_elements,
    store_in_chromadb,
    delete_irrelevant_images,
)

# %%
pdf_file = './data/MediumExample_Ears_17Pgs.pdf'
image_output_dir = './figures/Ears'
chroma_persist_dir = './chroma/Ears/'

# Make sure the data directory exists
assert os.path.exists('./data'), "Error: './data' directory not found."
assert os.path.exists(pdf_file), f"Error: PDF file not found at {pdf_file}."

# %%
print("📝 Unstructuring textbooks, filtering junks, semanic chunking...")
raw_pdf_elements = load_book(pdf_file, image_output_dir)
print("🎉 1.process_pdf_with_semantic_chunking complete.")
# Out:
# 📝 Unstructuring textbooks, filtering junks, semanic chunking...
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
# 🎉 1.process_pdf_with_semantic_chunking complete.

# %%
# Clean and categorize
texts, tables, images_raw, headers_raw, titles_raw, footers_raw, figure_captions_raw, list_items_raw = clean_and_categorize_elements(raw_pdf_elements, window_size=2, min_meaningful_text_length=75)

# %%
# Summarize, store, etc.
text_summaries, table_summaries, image_paths, relevant_images_to_summarize, image_summaries = summarize_elements(
    texts, tables, images_raw
)
# Out:
# Texts and Tables Summary Done!
# Checking image relevance with local textual context...
# Skipping decorative image: ./figures/Ears/figure-1-1.jpg
# Skipping decorative image: ./figures/Ears/figure-2-3.jpg
# Skipping decorative image: ./figures/Ears/figure-3-5.jpg
# Skipping decorative image: ./figures/Ears/figure-6-10.jpg
# Skipping decorative image: ./figures/Ears/figure-8-12.jpg
# Skipping decorative image: ./figures/Ears/figure-9-14.jpg
# Skipping decorative image: ./figures/Ears/figure-10-15.jpg
# Skipping decorative image: ./figures/Ears/figure-11-17.jpg
# Skipping decorative image: ./figures/Ears/figure-12-18.jpg
# Skipping decorative image: ./figures/Ears/figure-13-19.jpg
# Skipping decorative image: ./figures/Ears/figure-14-20.jpg
# Skipping decorative image: ./figures/Ears/figure-15-21.jpg
# Skipping decorative image: ./figures/Ears/figure-16-22.jpg
# Number of relevant images: 9
# Generating LLM summaries for relevant images...

# %%
retriever = store_in_chromadb(
    text_summaries, texts, table_summaries, tables, image_paths,
    relevant_images_to_summarize, image_summaries,
    persist_directory=chroma_persist_dir
)

# %%
delete_irrelevant_images(images_raw, relevant_images_to_summarize)
# Out:
# Successfully deleted irrelevant image: ./figures/Ears/figure-1-1.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-2-3.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-3-5.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-6-10.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-8-12.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-9-14.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-10-15.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-11-17.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-12-18.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-13-19.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-14-20.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-15-21.jpg
# Successfully deleted irrelevant image: ./figures/Ears/figure-16-22.jpg
# Finished deleting images. Total deleted: 13

# %%
# import os
sound_file = "/System/Library/Sounds/Glass.aiff"
os.system(f"afplay '{sound_file}'")
# Out:
# 0

# %% [markdown]
# # Inspecting Retrieved Docs

# %%
query = "What do cat intestinal parasites look like and how do they affect cats?"

# %%
from IPython.display import Image, display

print('-'*40, "Here are the retrieved original_docs with similarity scores",'-'*40)

results = retriever.retrieve_multi_modal(query, k=10)
for res in results:
    if res["modality"] == "image" and os.path.exists(res["summary"]):
        display(Image(filename=res["summary"]))
    print('-' * 40)
    print(f"🔎 Similarity Score: {res['score']:.4f}")
    print(f"🖼️ Modality: {res['modality']}")
    print("📝 Summary/Chunk:", res["summary"])
    print("Summary Metadata:", res["original_metadata"])
    print("Doc ID:", res["doc_id"])
# Out:
# ---------------------------------------- Here are the retrieved original_docs with similarity scores ----------------------------------------
# ----------------------------------------
# 🔎 Similarity Score: 1.4114
# 🖼️ Modality: image
# 📝 Summary/Chunk: ./figures/Ears/figure-4-6.jpg
# Summary Metadata: {'type': 'image', 'image_path': './figures/Ears/figure-4-6.jpg', 'doc_id': '9ac92912-1ced-4d3d-a89b-30cb4aded554', 'summary': "The image shows a veterinary assistant administering Epi-Otic to a cat's ear. The context suggests that this procedure involves preventing water from entering the cat's ears during bathing, which can prevent infections and treat any cuts or bites found in the pinna after a fight. It also mentions routine cleaning is not necessary but should be done when there is excessive wax buildup for maintaining tissue health."}
# Doc ID: 9ac92912-1ced-4d3d-a89b-30cb4aded554
# ----------------------------------------
# 🔎 Similarity Score: 1.3992
# 🖼️ Modality: image
# 📝 Summary/Chunk: ./figures/Ears/figure-3-4.jpg
# Summary Metadata: {'type': 'image', 'doc_id': 'de086559-946a-4b51-9c31-d30e27dd035f', 'summary': 'This image is not directly related to veterinary content. It appears to be an illustration of a cat with no specific focus on ears or any other anatomical feature relevant for veterinary purposes based on the provided local text context and filename information. The mention "THE EARS • 205" suggests it might relate to ear anatomy, but without further details, this cannot be confirmed from the image alone.', 'image_path': './figures/Ears/figure-3-4.jpg'}
# Doc ID: de086559-946a-4b51-9c31-d30e27dd035f
# ----------------------------------------
# 🔎 Similarity Score: 1.3781
# 🖼️ Modality: image
# 📝 Summary/Chunk: ./figures/Ears/figure-2-2.jpg
# Summary Metadata: {'summary': "The provided image is an anatomical illustration depicting various components of the human auditory system. It includes labels for different parts such as pinna (external ear), auditory nerve, window (tympanic membrane or eardrum), hammer (incus), anvil (malleus), stirrup (stapes), cochlea, and external auditory canal. This type of diagram is commonly used in veterinary education to teach about the anatomy relevant for diagnosing conditions affecting animals' hearing systems.", 'type': 'image', 'doc_id': '19b09196-5c83-493e-b0c2-f2a932daec2f', 'image_path': './figures/Ears/figure-2-2.jpg'}
# Doc ID: 19b09196-5c83-493e-b0c2-f2a932daec2f
# ----------------------------------------
# 🔎 Similarity Score: 1.3220
# 🖼️ Modality: image_summary
# 📝 Summary/Chunk: The image shows a veterinary assistant administering Epi-Otic to a cat's ear. The context suggests that this procedure involves preventing water from entering the cat's ears during bathing, which can prevent infections and treat any cuts or bites found in the pinna after a fight. It also mentions routine cleaning is not necessary but should be done when there is excessive wax buildup for maintaining tissue health.
# Summary Metadata: {'summary': "The image shows a veterinary assistant administering Epi-Otic to a cat's ear. The context suggests that this procedure involves preventing water from entering the cat's ears during bathing, which can prevent infections and treat any cuts or bites found in the pinna after a fight. It also mentions routine cleaning is not necessary but should be done when there is excessive wax buildup for maintaining tissue health.", 'type': 'image_summary', 'doc_id': '9ac92912-1ced-4d3d-a89b-30cb4aded554_context', 'image_path': './figures/Ears/figure-4-6.jpg'}
# Doc ID: 9ac92912-1ced-4d3d-a89b-30cb4aded554_context
# ----------------------------------------
# 🔎 Similarity Score: 1.3125
# 🖼️ Modality: image_summary
# 📝 Summary/Chunk: The image shows the ear of a cat displaying signs of hematoma, which is characterized by swelling and deformity in the pinna due to violent head shaking. The text suggests that this condition can affect both the skin of the ear canals as well as the pinna itself. It also mentions allergies or yeast infections could be mistaken for similar conditions; thus, consulting a veterinarian before applying any medication at home is advised.
# Summary Metadata: {'image_path': './figures/Ears/figure-9-13.jpg', 'type': 'image_summary', 'summary': 'The image shows the ear of a cat displaying signs of hematoma, which is characterized by swelling and deformity in the pinna due to violent head shaking. The text suggests that this condition can affect both the skin of the ear canals as well as the pinna itself. It also mentions allergies or yeast infections could be mistaken for similar conditions; thus, consulting a veterinarian before applying any medication at home is advised.', 'doc_id': 'cc9ca569-c024-4987-8679-3a64d478b74a_context'}
# Doc ID: cc9ca569-c024-4987-8679-3a64d478b74a_context
# ----------------------------------------
# 🔎 Similarity Score: 1.3007
# 🖼️ Modality: image_summary
# 📝 Summary/Chunk: The image depicts an individual applying medication into the ear canal of what appears to be a cat. The context provided suggests this is part of a veterinary handbook, specifically instructing how to apply ointment or instill drops in a pet's ear for treatment purposes. This demonstrates proper technique and care when administering medications directly into a pet’s ear canal.
# Summary Metadata: {'doc_id': 'ba3b992a-476a-445b-8706-608fea8a8ac9_context', 'image_path': './figures/Ears/figure-6-9.jpg', 'summary': "The image depicts an individual applying medication into the ear canal of what appears to be a cat. The context provided suggests this is part of a veterinary handbook, specifically instructing how to apply ointment or instill drops in a pet's ear for treatment purposes. This demonstrates proper technique and care when administering medications directly into a pet’s ear canal.", 'type': 'image_summary'}
# Doc ID: ba3b992a-476a-445b-8706-608fea8a8ac9_context
# ----------------------------------------
# 🔎 Similarity Score: 1.3000
# 🖼️ Modality: image_summary
# 📝 Summary/Chunk: The image shows a veterinary assistant performing an ear cleaning procedure on a cat. The veterinarian is using their fingers to gently hold down the cat's ear while another hand appears to be applying or massaging an ear-cleaning solution into the base of the cat's ear canal, as described in the local text context provided. This demonstrates proper technique for maintaining cleanliness and health within a cat's ears.
# Summary Metadata: {'doc_id': '9a488c79-c0a4-449e-8bf9-52db769a8331_context', 'image_path': './figures/Ears/figure-4-7.jpg', 'type': 'image_summary', 'summary': "The image shows a veterinary assistant performing an ear cleaning procedure on a cat. The veterinarian is using their fingers to gently hold down the cat's ear while another hand appears to be applying or massaging an ear-cleaning solution into the base of the cat's ear canal, as described in the local text context provided. This demonstrates proper technique for maintaining cleanliness and health within a cat's ears."}
# Doc ID: 9a488c79-c0a4-449e-8bf9-52db769a8331_context
# ----------------------------------------
# 🔎 Similarity Score: 1.2926
# 🖼️ Modality: image_summary
# 📝 Summary/Chunk: The provided local text indicates that this image is part of an educational or informative series focusing on veterinary anatomy. The specific reference to "THE EARS" suggests the content may be related to ear structure, function, and possibly conditions affecting them.
#
# Given the context and the visible elements in the image, it appears to show a close-up view of a cat's ears being examined by a human hand, likely for educational purposes or as part of an instructional guide on veterinary care. The focus is on demonstrating how to inspect ear anatomy during a routine examination.
#
# Without additional information about the specific context within which this image was created, such as whether it belongs in a textbook, online resource, or other medium, further details cannot be provided beyond what has been described here.
# Summary Metadata: {'doc_id': '5c1b30a0-1ee7-4cf6-9739-449565ffaebe_context', 'summary': 'The provided local text indicates that this image is part of an educational or informative series focusing on veterinary anatomy. The specific reference to "THE EARS" suggests the content may be related to ear structure, function, and possibly conditions affecting them.\n\nGiven the context and the visible elements in the image, it appears to show a close-up view of a cat\'s ears being examined by a human hand, likely for educational purposes or as part of an instructional guide on veterinary care. The focus is on demonstrating how to inspect ear anatomy during a routine examination.\n\nWithout additional information about the specific context within which this image was created, such as whether it belongs in a textbook, online resource, or other medium, further details cannot be provided beyond what has been described here.', 'type': 'image_summary', 'image_path': './figures/Ears/figure-11-16.jpg'}
# Doc ID: 5c1b30a0-1ee7-4cf6-9739-449565ffaebe_context
# ----------------------------------------
# 🔎 Similarity Score: 1.1455
# 🖼️ Modality: image_summary
# 📝 Summary/Chunk: The image shows a cat with its head wrapped in what appears to be a bandage, likely for protection and healing after an injury. The context suggests that such injuries are common among cats due to bites, scratches, or mating activities, leading to potential infections at the ear site. An ear bandage is mentioned as part of treatment for these types of wounds.
# Summary Metadata: {'doc_id': 'c97612b4-4a14-4333-b828-59ef2e6d20e8_context', 'image_path': './figures/Ears/figure-7-11.jpg', 'type': 'image_summary', 'summary': 'The image shows a cat with its head wrapped in what appears to be a bandage, likely for protection and healing after an injury. The context suggests that such injuries are common among cats due to bites, scratches, or mating activities, leading to potential infections at the ear site. An ear bandage is mentioned as part of treatment for these types of wounds.'}
# Doc ID: c97612b4-4a14-4333-b828-59ef2e6d20e8_context
# ----------------------------------------
# 🔎 Similarity Score: 0.9782
# 🖼️ Modality: image_summary
# 📝 Summary/Chunk: This image is not directly related to veterinary content. It appears to be an illustration of a cat with no specific focus on ears or any other anatomical feature relevant for veterinary purposes based on the provided local text context and filename information. The mention "THE EARS • 205" suggests it might relate to ear anatomy, but without further details, this cannot be confirmed from the image alone.
# Summary Metadata: {'summary': 'This image is not directly related to veterinary content. It appears to be an illustration of a cat with no specific focus on ears or any other anatomical feature relevant for veterinary purposes based on the provided local text context and filename information. The mention "THE EARS • 205" suggests it might relate to ear anatomy, but without further details, this cannot be confirmed from the image alone.', 'doc_id': 'de086559-946a-4b51-9c31-d30e27dd035f_context', 'image_path': './figures/Ears/figure-3-4.jpg', 'type': 'image_summary'}
# Doc ID: de086559-946a-4b51-9c31-d30e27dd035f_context
# ----------------------------------------
# 🔎 Similarity Score: 0.9143
# 🖼️ Modality: text
# 📝 Summary/Chunk: Longhaired cats with blue eyes are more prone to deafness, as well as white cats (especially those with the Siamese dilution gene) and cats with only one blue eye. Congenitally deaf cats should not be bred. Breeds listed at higher risk for congenital deafness due to white coat pigment include: [list of breeds].
# Summary Metadata: {'type': 'text', 'doc_id': 'da37272c-2f35-4e2a-abee-71eec0beafd8'}
# Doc ID: da37272c-2f35-4e2a-abee-71eec0beafd8
# ----------------------------------------
# 🔎 Similarity Score: 0.8929
# 🖼️ Modality: text
# 📝 Summary/Chunk: Here is a concise summary:
#
# **Bacterial Otitis Externa in Cats**
#
# Causes: scratches, bites, excess wax or debris
# Signs: shaking head, scratching, odor, redness and swelling
#
# Treatment:
# - Mild cases: clean ears at home with cotton balls and ear-cleaning solution
# - More severe cases: seek veterinary advice for diagnosis and treatment.
# Summary Metadata: {'type': 'text', 'doc_id': '528a70c2-4030-4712-abf1-8dc979f61282'}
# Doc ID: 528a70c2-4030-4712-abf1-8dc979f61282
# ----------------------------------------
# 🔎 Similarity Score: 0.8834
# 🖼️ Modality: text
# 📝 Summary/Chunk: Benign ceruminous gland cysts occur in cats' ears, appearing as dark lesions or clusters resembling grapes. They typically don't cause issues but can block the ear canal if left untreated. Malignant ceruminous gland tumors (adenocarcinomas) are also common and must be distinguished from ear polyps.
# Summary Metadata: {'type': 'text', 'doc_id': '68ab2b9c-ff2e-43da-92ee-8349dc8dda06'}
# Doc ID: 68ab2b9c-ff2e-43da-92ee-8349dc8dda06
# ----------------------------------------
# 🔎 Similarity Score: 0.8743
# 🖼️ Modality: text
# 📝 Summary/Chunk: Here is a concise summary of the text:
#
# Ear mites are common in cats, causing intense itching, head shaking, and dry, crumbly ear discharge (coffee ground-like appearance). Symptoms worsen with allergic reactions or irritation. Suspect ear mites when both ears are affected and look for this discharge, which can be foul-smelling.
# Summary Metadata: {'doc_id': 'd2939ef4-7e25-40a3-ac19-d53afabb72d2', 'type': 'text'}
# Doc ID: d2939ef4-7e25-40a3-ac19-d53afabb72d2
# ----------------------------------------
# 🔎 Similarity Score: 0.8463
# 🖼️ Modality: text
# 📝 Summary/Chunk: Cats can be born without hearing due to developmental defects. Congenital deafness is more common in:
#
# * White cats
# * Blue-eyed cats
# * One ear may be deaf, not both.
#
# Note: Genetics play a role, but not all blue-eyed cats are deaf and not all white cats with blue eyes are affected.
# Summary Metadata: {'doc_id': '1ffe2d2e-0cde-48a9-a968-2a5d871f0f86', 'type': 'text'}
# Doc ID: 1ffe2d2e-0cde-48a9-a968-2a5d871f0f86
# ----------------------------------------
# 🔎 Similarity Score: 0.8425
# 🖼️ Modality: text
# 📝 Summary/Chunk: Key information:
#
# * Otitis interna is an inner ear infection that can start as a middle ear infection.
# * Symptoms include vomiting, staggering, falling towards one side, and rhythmic eye movements.
# * Ear medications can cause permanent damage if not used properly.
#
# Actionable advice:
#
# * Have a veterinarian examine the cat's ears before medicating or flushing them to avoid causing damage.
# * Seek veterinary treatment for inner ear infections, as they may require surgery in severe cases.
# Summary Metadata: {'doc_id': '20431ed9-e5a4-49dc-a385-c65f857ff476', 'type': 'text'}
# Doc ID: 20431ed9-e5a4-49dc-a385-c65f857ff476
# ----------------------------------------
# 🔎 Similarity Score: 0.8312
# 🖼️ Modality: text
# 📝 Summary/Chunk: Here's a concise summary:
#
# Ear polyps in cats are growths primarily seen in cats between 1-4 years old, caused by chronic inflammation or developmental defect. Symptoms include head shaking, ear discharge, pain, and breathing problems. Treatment involves surgical removal of the polyp, with follow-up corticosteroids to reduce recurrence risk (up to 20%).
# Summary Metadata: {'doc_id': '4f7562ff-0fb2-49b0-be9b-b7f4afe42ba2', 'type': 'text'}
# Doc ID: 4f7562ff-0fb2-49b0-be9b-b7f4afe42ba2
# ----------------------------------------
# 🔎 Similarity Score: 0.7869
# 🖼️ Modality: text
# 📝 Summary/Chunk: Key signs of an ear problem in cats include:
#
# * Ear scratching or shaking
# * Bad odor from the ear
# * Waxy discharge or pus draining
# * Head tilt and loss of hearing (middle ear disease)
# * Balance issues, wobbling, and trouble righting oneself (inner ear disease)
# * Rapid eye jerking movements (nystagmus)
# Summary Metadata: {'doc_id': 'c155b851-c3d8-45b3-9509-6f29dba41452', 'type': 'text'}
# Doc ID: c155b851-c3d8-45b3-9509-6f29dba41452
# ----------------------------------------
# 🔎 Similarity Score: 0.7631
# 🖼️ Modality: text
# 📝 Summary/Chunk: Cats frequently suffer from painful bites and scratches, especially around the ear (pinna), which can lead to severe infections. These incidents sometimes occur during mating.
# Summary Metadata: {'doc_id': 'cd66810a-2a7e-4a9d-8ee0-2c88671b37bf', 'type': 'text'}
# Doc ID: cd66810a-2a7e-4a9d-8ee0-2c88671b37bf
# ----------------------------------------
# 🔎 Similarity Score: 0.6960
# 🖼️ Modality: text
# 📝 Summary/Chunk: Otitis Media in cats is rare and usually caused by an external ear infection that ruptures the eardrum or by bacterial infections spreading through the Eustachian tube from other parts of the body, such as tonsillitis or sinus infections.
# Summary Metadata: {'type': 'text', 'doc_id': '71b93f03-d93f-458d-9f1f-14d7a1d3f8d4'}
# Doc ID: 71b93f03-d93f-458d-9f1f-14d7a1d3f8d4

# %%
# Only images
image_results = retriever.retrieve(query, k=10, filter={"type": "image"})
# Only text
text_results = retriever.retrieve(query, k=10, filter={"type": "text"})
